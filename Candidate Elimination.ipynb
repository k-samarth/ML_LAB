# %%
import random
import csv
def g_0(n):
    return ('?',)*n

def s_0(n):
    return ("ɸ",)*n
def more_general(h1, h2):
    more_general_parts = []
    for x, y in zip(h1, h2):
        mg = x == "?" or (x != "ɸ" and (x == y or y == "ɸ"))
        more_general_parts.append(mg)
    return all(more_general_parts)
def fulfills(example, hypothesis):
    return more_general(hypothesis, example)

def min_generalizations(h, x):
    h_new = list(h)
    for i in range(len(h)):
        if not fulfills(x[i:i+1], h[i:i+1]):
            h_new[i] = '?' if h[i] != 'ɸ' else x[i]
    return [tuple(h_new)]
def min_specializations(h, domains, x):
    results = []
    for i in range(len(h)):
        if h[i] == "?":
            for val in domains[i]:
                if x[i] != val:
                    h_new = h[:i] + (val,) + h[i+1:]
                    results.append(h_new)
        elif h[i] != "ɸ":
            h_new = h[:i] + ('ɸ',) + h[i+1:]
            results.append(h_new)
    return results
with open('trainingexamples.csv') as csvFile:
    examples = [tuple(line) for line in csv.reader(csvFile)]
def get_domains(examples):
    d = [set() for i in examples[0]]
    for x in examples:
        for i, xi in enumerate(x):
            d[i].add(xi)
    return [list(sorted(x)) for x in d]
get_domains(examples)


def candidate_elimination(examples):
    domains = get_domains(examples)[:-1]

    G = set([g_0(len(domains))])
    S = set([s_0(len(domains))])
    i = 0
    print("\n G[{0}]:".format(i), G)
    print("\n S[{0}]:".format(i), S)
    for xcx in examples:
        i = i + 1
        x, cx = xcx[:-1], xcx[-1]
        if cx == 'Y':
            G = {g for g in G if fulfills(x, g)}
            S = generalize_S(x, G, S)
        else:
            S = {s for s in S if not fulfills(x, s)}
            G = specialize_G(x, domains, G, S)
        print("\n G[{0}]:".format(i), G)
        print("\n S[{0}]:".format(i), S)
    return
def generalize_S(x, G, S):
    S_prev = list(S)
    for s in S_prev:
        if s not in S:
            continue
        if not fulfills(x, s):
            S.remove(s)
            Splus = min_generalizations(s, x)
            S.update([h for h in Splus if any([more_general(g,h)
                                               for g in G])])
            S.difference_update([h for h in S if
                                 any([more_general(h, h1)
                                      for h1 in S if h != h1])])
    return S
def specialize_G(x, domains, G, S):
    G_prev = list(G)
    for g in G_prev:
        if g not in G:
            continue
        if fulfills(x, g):
            G.remove(g)
            Gminus = min_specializations(g, domains, x)
            G.update([h for h in Gminus if any([more_general(h, s)
                                                for s in S])])
            G.difference_update([h for h in G if
                                 any([more_general(g1, h)
                                      for g1 in G if h != g1])])
    return G
candidate_elimination(examples)
# Out:
#  G[0]: {('?', '?', '?', '?', '?', '?', '?')}
#
#  S[0]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
#
#  G[1]: {('?', 'Sunny', '?', '?', '?', '?', '?'), ('3', '?', '?', '?', '?', '?', '?'), ('?', '?', '?', 'High', '?', '?', '?'), ('?', '?', '?', '?', 'Strong', '?', '?'), ('?', '?', 'Cool', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', 'Warm', '?'), ('?', '?', '?', 'Normal', '?', '?', '?'), ('2', '?', '?', '?', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', '?', 'Same'), ('4', '?', '?', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', 'Cool', '?'), ('1', '?', '?', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', '?', 'Change')}
#
#  S[1]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
#
#  G[2]: {('3', '?', '?', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', 'Water', 'Same'), ('?', '?', 'Cool', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', 'Wind', '?', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Same'), ('?', '?', '?', '?', '?', 'Cool', '?'), ('?', 'Sunny', '?', '?', '?', '?', 'Forecast'), ('?', 'Sky', '?', '?', '?', 'Warm', '?'), ('?', '?', 'Air Temp', '?', '?', '?', 'Same'), ('?', '?', 'Warm', '?', '?', '?', 'Forecast'), ('?', 'Sunny', '?', '?', 'Wind', '?', '?'), ('Example', '?', '?', '?', 'Strong', '?', '?'), ('1', '?', 'Air Temp', '?', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', 'Water', '?'), ('1', '?', '?', '?', '?', 'Water', '?'), ('?', '?', 'Warm', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'High', '?', '?', '?'), ('?', '?', '?', '?', 'Strong', 'Water', '?'), ('Example', '?', '?', 'Normal', '?', '?', '?'), ('?', 'Sky', '?', '?', '?', '?', 'Same'), ('2', '?', '?', '?', '?', '?', '?'), ('4', '?', '?', '?', '?', '?', '?'), ('1', '?', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'Humidity', '?', 'Warm', '?'), ('Example', '?', '?', '?', '?', '?', 'Same'), ('?', '?', 'Air Temp', '?', 'Strong', '?', '?'), ('?', 'Sunny', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', '?', 'Wind', 'Warm', '?'), ('?', '?', '?', '?', '?', 'Warm', 'Forecast'), ('?', 'Sky', '?', '?', 'Strong', '?', '?'), ('?', '?', '?', 'Humidity', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'Normal', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', 'Water', '?'), ('?', 'Sky', 'Warm', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', '?', 'Change'), ('?', 'Sky', '?', 'Normal', '?', '?', '?'), ('1', 'Sky', '?', '?', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', '?', '?'), ('?', 'Sunny', 'Air Temp', '?', '?', '?', '?'), ('Example', '?', 'Warm', '?', '?', '?', '?'), ('Example', '?', '?', '?', '?', 'Warm', '?'), ('1', '?', '?', '?', '?', '?', 'Forecast'), ('?', '?', '?', 'Normal', 'Wind', '?', '?'), ('Example', 'Sunny', '?', '?', '?', '?', '?'), ('1', '?', '?', '?', 'Wind', '?', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Forecast'), ('?', '?', '?', 'Humidity', '?', '?', 'Same'), ('?', 'Sunny', '?', '?', '?', 'Water', '?'), ('?', '?', '?', '?', 'Strong', '?', 'Forecast'), ('?', '?', 'Air Temp', '?', '?', 'Warm', '?')}
#
#  S[2]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
#
#  G[3]: {('3', '?', '?', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', 'Water', 'Same'), ('2', '?', '?', '?', '?', '?', 'Forecast'), ('?', '?', 'Cool', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', 'Wind', '?', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Same'), ('?', '?', '?', '?', '?', 'Cool', '?'), ('?', 'Sunny', '?', '?', '?', '?', 'Forecast'), ('?', 'Sky', '?', '?', '?', 'Warm', '?'), ('?', '?', 'Air Temp', '?', '?', '?', 'Same'), ('?', '?', 'Warm', '?', '?', '?', 'Forecast'), ('?', 'Sunny', '?', '?', 'Wind', '?', '?'), ('Example', '?', '?', '?', 'Strong', '?', '?'), ('1', '?', 'Air Temp', '?', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', 'Water', '?'), ('1', '?', '?', '?', '?', 'Water', '?'), ('?', '?', 'Warm', 'Humidity', '?', '?', '?'), ('?', '?', '?', '?', 'Strong', 'Water', '?'), ('Example', '?', '?', 'Normal', '?', '?', '?'), ('?', 'Sky', '?', '?', '?', '?', 'Same'), ('4', '?', '?', '?', '?', '?', '?'), ('1', '?', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'Humidity', '?', 'Warm', '?'), ('Example', '?', '?', '?', '?', '?', 'Same'), ('?', '?', '?', 'High', '?', 'Water', '?'), ('?', '?', 'Air Temp', '?', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'High', '?', '?', '?'), ('?', 'Sunny', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', '?', 'Wind', 'Warm', '?'), ('?', '?', '?', '?', '?', 'Warm', 'Forecast'), ('?', 'Sky', '?', '?', 'Strong', '?', '?'), ('?', 'Sky', '?', 'High', '?', '?', '?'), ('?', '?', '?', 'Humidity', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'Normal', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', 'Water', '?'), ('?', 'Sky', 'Warm', '?', '?', '?', '?'), ('?', '?', '?', '?', '?', '?', 'Change'), ('?', 'Sky', '?', 'Normal', '?', '?', '?'), ('1', 'Sky', '?', '?', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', '?', '?'), ('?', 'Sunny', 'Air Temp', '?', '?', '?', '?'), ('Example', '?', '?', 'High', '?', '?', '?'), ('2', '?', '?', 'Humidity', '?', '?', '?'), ('Example', '?', 'Warm', '?', '?', '?', '?'), ('Example', '?', '?', '?', '?', 'Warm', '?'), ('1', '?', '?', '?', '?', '?', 'Forecast'), ('1', '?', '?', 'High', '?', '?', '?'), ('?', '?', '?', 'Normal', 'Wind', '?', '?'), ('Example', 'Sunny', '?', '?', '?', '?', '?'), ('1', '?', '?', '?', 'Wind', '?', '?'), ('?', '?', '?', 'High', 'Wind', '?', '?'), ('2', '?', '?', '?', '?', 'Water', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Forecast'), ('?', '?', '?', 'Humidity', '?', '?', 'Same'), ('2', '?', 'Air Temp', '?', '?', '?', '?'), ('2', '?', '?', '?', 'Wind', '?', '?'), ('2', 'Sky', '?', '?', '?', '?', '?'), ('?', 'Sunny', '?', '?', '?', 'Water', '?'), ('2', '?', '?', 'Normal', '?', '?', '?'), ('?', '?', '?', '?', 'Strong', '?', 'Forecast'), ('?', '?', '?', 'High', '?', '?', 'Forecast'), ('?', '?', 'Air Temp', '?', '?', 'Warm', '?')}
#
#  S[3]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
#
#  G[4]: {('?', '?', 'Cool', '?', '?', '?', 'Same'), ('?', '?', '?', '?', '?', 'Water', 'Same'), ('3', '?', '?', '?', '?', 'Water', '?'), ('?', 'Sunny', '?', '?', '?', '?', 'Change'), ('2', '?', '?', '?', '?', '?', 'Forecast'), ('2', 'Rain', '?', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', 'Wind', '?', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Same'), ('?', '?', '?', '?', '?', 'Cool', '?'), ('?', '?', 'Warm', '?', '?', '?', 'Change'), ('?', '?', '?', 'Humidity', '?', '?', 'Change'), ('?', '?', 'Cool', 'Humidity', '?', '?', '?'), ('?', 'Sunny', '?', '?', '?', '?', 'Forecast'), ('?', 'Sky', '?', '?', '?', 'Warm', '?'), ('?', '?', 'Air Temp', '?', '?', '?', 'Same'), ('?', 'Rain', 'Warm', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', '?', 'Forecast'), ('?', 'Sunny', '?', '?', 'Wind', '?', '?'), ('?', 'Rain', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', '?', '?', 'Water', 'Change'), ('Example', '?', '?', '?', 'Strong', '?', '?'), ('1', '?', 'Air Temp', '?', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', 'Water', '?'), ('1', '?', '?', '?', '?', 'Water', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Change'), ('?', '?', 'Warm', 'Humidity', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', 'Water', '?'), ('?', '?', '?', '?', 'Strong', 'Water', '?'), ('3', '?', '?', '?', 'Wind', '?', '?'), ('Example', '?', '?', 'Normal', '?', '?', '?'), ('?', 'Sky', '?', '?', '?', '?', 'Same'), ('3', 'Sky', '?', '?', '?', '?', '?'), ('?', '?', 'Air Temp', '?', '?', '?', 'Change'), ('4', '?', '?', '?', '?', '?', '?'), ('1', '?', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'Humidity', '?', 'Warm', '?'), ('Example', '?', '?', '?', '?', '?', 'Same'), ('?', '?', '?', 'High', '?', 'Water', '?'), ('?', 'Rain', 'Air Temp', '?', '?', '?', '?'), ('?', '?', 'Air Temp', '?', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'High', '?', '?', '?'), ('?', '?', 'Cool', '?', 'Wind', '?', '?'), ('?', 'Rain', '?', '?', '?', '?', 'Forecast'), ('?', 'Sky', '?', '?', '?', '?', 'Change'), ('?', 'Sunny', '?', 'Humidity', '?', '?', '?'), ('1', 'Rain', '?', '?', '?', '?', '?'), ('?', 'Rain', '?', '?', 'Wind', '?', '?'), ('?', '?', '?', '?', 'Wind', 'Warm', '?'), ('?', '?', '?', '?', '?', 'Warm', 'Forecast'), ('3', '?', '?', 'Humidity', '?', '?', '?'), ('Example', '?', 'Cool', '?', '?', '?', '?'), ('?', 'Sky', '?', '?', 'Strong', '?', '?'), ('?', 'Sky', '?', 'High', '?', '?', '?'), ('Example', '?', '?', '?', '?', '?', 'Change'), ('?', '?', '?', 'Humidity', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'Normal', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', 'Water', '?'), ('2', '?', 'Cool', '?', '?', '?', '?'), ('?', 'Sky', 'Warm', '?', '?', '?', '?'), ('?', 'Sky', '?', 'Normal', '?', '?', '?'), ('?', '?', 'Cool', '?', '?', 'Water', '?'), ('?', 'Rain', '?', '?', '?', '?', 'Same'), ('1', 'Sky', '?', '?', '?', '?', '?'), ('?', 'Sunny', 'Air Temp', '?', '?', '?', '?'), ('Example', '?', '?', 'High', '?', '?', '?'), ('2', '?', '?', 'Humidity', '?', '?', '?'), ('3', '?', '?', '?', '?', '?', 'Forecast'), ('Example', '?', 'Warm', '?', '?', '?', '?'), ('3', '?', '?', 'Normal', '?', '?', '?'), ('1', '?', '?', '?', '?', '?', 'Change'), ('?', '?', 'Cool', '?', '?', '?', 'Forecast'), ('3', 'Sunny', '?', '?', '?', '?', '?'), ('3', '?', 'Air Temp', '?', '?', '?', '?'), ('Example', '?', '?', '?', '?', 'Warm', '?'), ('?', 'Sunny', 'Cool', '?', '?', '?', '?'), ('1', '?', '?', '?', '?', '?', 'Forecast'), ('Example', 'Rain', '?', '?', '?', '?', '?'), ('1', '?', 'Cool', '?', '?', '?', '?'), ('1', '?', '?', 'High', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Change'), ('?', '?', '?', 'Normal', 'Wind', '?', '?'), ('?', 'Sky', 'Cool', '?', '?', '?', '?'), ('Example', 'Sunny', '?', '?', '?', '?', '?'), ('1', '?', '?', '?', 'Wind', '?', '?'), ('?', '?', '?', 'High', 'Wind', '?', '?'), ('3', '?', 'Warm', '?', '?', '?', '?'), ('2', '?', '?', '?', '?', 'Water', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Forecast'), ('?', '?', 'Cool', 'Normal', '?', '?', '?'), ('?', '?', '?', 'Humidity', '?', '?', 'Same'),  ...
#
#  S[4]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
#
#  G[5]: {('3', '?', '?', '?', '?', 'Water', '?'), ('2', '?', '?', '?', '?', '?', 'Forecast'), ('2', 'Rain', '?', '?', '?', '?', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Same'), ('?', '?', '?', 'Humidity', '?', '?', 'Change'), ('?', 'Sky', '?', '?', '?', 'Warm', '?'), ('?', 'Sunny', '?', '?', 'Wind', '?', '?'), ('?', 'Rain', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', 'Water', '?'), ('?', '?', '?', '?', 'Wind', '?', 'Change'), ('4', '?', '?', 'Normal', '?', '?', '?'), ('?', '?', 'Warm', 'Humidity', '?', '?', '?'), ('?', 'Sky', '?', '?', '?', '?', 'Same'), ('1', '?', '?', 'Humidity', '?', '?', '?'), ('2', '?', '?', '?', '?', 'Cool', '?'), ('?', '?', 'Air Temp', 'High', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', '?', 'Forecast'), ('?', 'Sunny', '?', '?', '?', 'Warm', 'Change'), ('?', 'Sky', '?', '?', '?', '?', 'Change'), ('4', '?', '?', '?', '?', 'Water', '?'), ('Example', '?', '?', '?', '?', 'Cool', '?'), ('3', '?', '?', 'Humidity', '?', '?', '?'), ('?', 'Sky', '?', '?', 'Strong', '?', '?'), ('?', '?', '?', 'Humidity', 'Strong', '?', '?'), ('?', '?', 'Air Temp', 'Normal', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', 'Water', '?'), ('?', 'Sky', 'Warm', '?', '?', '?', '?'), ('?', '?', '?', '?', 'Wind', 'Cool', '?'), ('?', 'Sky', '?', 'Normal', '?', '?', '?'), ('?', '?', 'Cool', '?', '?', 'Water', '?'), ('1', '?', '?', '?', '?', 'Cool', '?'), ('?', '?', 'Cool', '?', '?', 'Cool', '?'), ('4', 'Rain', '?', '?', '?', '?', '?'), ('4', '?', 'Air Temp', '?', '?', '?', '?'), ('4', '?', '?', '?', '?', 'Warm', '?'), ('?', '?', 'Air Temp', '?', '?', 'Cool', '?'), ('4', '?', '?', '?', 'Wind', '?', '?'), ('4', 'Sky', '?', '?', '?', '?', '?'), ('Example', '?', '?', 'High', '?', '?', '?'), ('?', 'Rain', '?', '?', '?', 'Cool', '?'), ('2', '?', '?', 'Humidity', '?', '?', '?'), ('3', '?', '?', '?', '?', '?', 'Forecast'), ('Example', '?', '?', '?', '?', 'Warm', '?'), ('4', '?', '?', '?', '?', '?', 'Same'), ('1', '?', '?', 'High', '?', '?', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Change'), ('3', '?', '?', '?', '?', '?', 'Same'), ('?', 'Sky', 'Cool', '?', '?', '?', '?'), ('Example', 'Sunny', '?', '?', '?', '?', '?'), ('1', '?', '?', '?', 'Wind', '?', '?'), ('?', '?', '?', 'High', 'Wind', '?', '?'), ('3', '?', 'Warm', '?', '?', '?', '?'), ('2', '?', '?', '?', '?', 'Water', '?'), ('?', '?', '?', 'Normal', '?', '?', 'Forecast'), ('?', '?', 'Warm', '?', '?', 'Warm', 'Change'), ('?', '?', 'Cool', 'Normal', '?', '?', '?'), ('2', '?', 'Air Temp', '?', '?', '?', '?'), ('?', '?', 'Air Temp', '?', '?', 'Warm', '?'), ('?', '?', 'Cool', '?', '?', '?', 'Same'), ('?', '?', '?', '?', '?', 'Water', 'Same'), ('?', '?', '?', '?', '?', 'Cool', 'Same'), ('4', '?', '?', '?', '?', '?', 'Forecast'), ('?', '?', 'Warm', '?', 'Wind', '?', '?'), ('?', '?', 'Cool', 'Humidity', '?', '?', '?'), ('?', 'Sunny', '?', '?', '?', '?', 'Forecast'), ('?', '?', 'Air Temp', '?', '?', '?', 'Same'), ('?', 'Rain', 'Warm', '?', '?', '?', '?'), ('?', '?', 'Warm', '?', '?', '?', 'Forecast'), ('?', '?', '?', '?', '?', 'Water', 'Change'), ('Example', '?', '?', '?', 'Strong', '?', '?'), ('1', '?', 'Air Temp', '?', '?', '?', '?'), ('1', '?', '?', '?', '?', 'Water', '?'), ('?', 'Rain', '?', '?', '?', 'Water', '?'), ('?', '?', '?', '?', 'Strong', 'Water', '?'), ('3', '?', '?', '?', 'Wind', '?', '?'), ('Example', '?', '?', 'Normal', '?', '?', '?'), ('3', 'Sky', '?', '?', '?', '?', '?'), ('?', '?', 'Air Temp', '?', '?', '?', 'Change'), ('4', '?', '?', 'Humidity', '?', '?', '?'), ('?', '?', '?', 'Humidity', '?', 'Warm', '?'), ('Example', '?', '?', '?', '?', '?', 'Same'), ('?', '?', '?', 'High', '?', 'Water', '?'), ('?', 'Rain', 'Air Temp', '?', '?', '?', '?'), ('?', '?', 'Air Temp', '?', 'Strong', '?', '?'), ('4', '?', 'Cool', '?', '?', '?', '?'), ('?', '?', 'Cool', '?', 'Wind', '?', '?'), ('?', 'Sunny', '?', 'Humidity', '?', '?', '?'), ('1', 'Rain', '?', '?', '?', '?', '?'), ('?', 'Rain', '?', '?', 'Wind', '?', '?'), ('3', '?', '?', '?', '?', 'Cool', '?'), ('?', '?', '?', '?', 'Win ...
#
#  S[5]: {('ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ', 'ɸ')}
